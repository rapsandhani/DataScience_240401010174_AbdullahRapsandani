# %% [markdown]
# <a href="https://colab.research.google.com/github/rapsandhani/DataScience_240401010174_AbdullahRapsandani/blob/main/Pertemuan1_AbdullahRapsandani_240401010174.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > Tambahkan blockquote

# %% [markdown]
# #### Nama Lengkap  : Abdullah Rapsandani
# #### NIM           : 240401010174
# #### Kelas         : IF403

# %% [markdown]
# # **Sesi 1 – Pengenalan Data Science**

# %% [markdown]
# #### SEL 1: Output sederhana
#
# > Tambahkan blockquote

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %% [markdown]
# #### SEL 2: Variabel dan tipe data dasar

# %%
nama = "Abdullah Rapsandani" # String
angkatan = 2024 # Integer
ipk = 3.65 # Float
aktif = True # Boolean

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Abdullah Rapsandani
# Angkatan: 2024
# IPK : 3.65
# Aktif : True

# %% [markdown]
# #### SEL 3: List dan perulangan

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
 print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %% [markdown]
# #### SEL 4: Fungsi sederhana

# %%
def perkenalan(nama, prodi, angkatan):
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Abdullah Rapsandani", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Abdullah Rapsandani dari Informatika, angkatan 2024.

# %% [markdown]
# #### Kesimpulan
#
# ---

# %% [markdown]
# saya mempelajari dasar penggunaan Google Colab, menjalankan program Python sederhana, membuat fungsi dan perulangan, serta menggunakan GitHub sebagai media penyimpanan dan pengumpulan tugas. Aktivitas ini menjadi langkah awal untuk mempelajari Data Science yang menggabungkan pemrograman, pengolahan data, dan kolaborasi proyek.
