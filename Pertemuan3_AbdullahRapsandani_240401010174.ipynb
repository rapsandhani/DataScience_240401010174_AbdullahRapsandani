# %% [markdown]
# <a href="https://colab.research.google.com/github/rapsandhani/DataScience_240401010174_AbdullahRapsandani/blob/main/Pertemuan3_AbdullahRapsandani_240401010174.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Nama Lengkap  : Abdullah Rapsandani
# #### NIM           : 240401010174
# #### Kelas         : IF403

# %% [markdown]
# # **Sesi 3 – Data Cleaning: Missing, Outlier & Ekstraksii**

# %% [markdown]
# # STEP 0 — Load & eksplorasi awal

# %%
import pandas as pd
import numpy as np
from scipy.stats.mstats import winsorize
import requests
from pandas import json_normalize

URL = "https://drive.google.com/uc?id=1LfQWProB0VjWN5q8bKuRIgn-stULfIRo"
df = pd.read_csv(URL)

df.info()
df.describe()
print('Shape awal:', df.shape)
print(df.isnull().sum())

# %% [markdown]
# # STEP 1 — Hapus Duplikat

# %%
df.drop_duplicates(inplace=True)
print('Setelah hapus duplikat:', df.shape)

# %% [markdown]
# # STEP 2 — Normalisasi String

# %%
print('Nilai unik kolom [kota] SEBELUM normalisasi:')
print(df['kota'].unique())
print('\nNilai unik kolom [kondisi] SEBELUM normalisasi:')
print(df['kondisi'].unique())

# %%
df['kota'] = df['kota'].str.strip().str.title()
df['kondisi'] = df['kondisi'].str.strip().str.lower()

# %%
print('Nilai unik kolom [kota] SETELAH normalisasi:')
print(df['kota'].unique())
print('\nNilai unik kolom [kondisi] SETELAH normalisasi:')
print(df['kondisi'].unique())

# %% [markdown]
# # STEP 3 — Imputasi Missing Values

# %%
df['luas_m2'] = df['luas_m2'].fillna(df['luas_m2'].median())
df['harga_juta'] = df['harga_juta'].fillna(df['harga_juta'].median())
df['kamar'] = df['kamar'].fillna(df['kamar'].mode()[0])
print(f'\nMissing values setelah imputasi: {df.isnull().sum().sum()}')

# %% [markdown]
# # STEP 4 — Tangani Outlier (IQR Fence)

# %%
for col in ['harga_juta', 'luas_m2', 'tahun_bangun']:
 Q1, Q3 = df[col].quantile([0.25, 0.75])
 IQR = Q3 - Q1
 df[col] = df[col].clip(Q1-1.5*IQR, Q3+1.5*IQR)

# %% [markdown]
# # STEP 5 — Validasi & Ekspor

# %%
assert df.isnull().sum().sum() == 0, 'Masih ada missing!'
assert df.duplicated().sum() == 0, 'Masih ada duplikat!'
print('Shape akhir:', df.shape)
df.to_csv('housing_clean.csv', index=False)
print('Dataset bersih tersimpan!')

# %% [markdown]
# # Kesimpulan
#
# ---

# %% [markdown]
# Praktikum ini memberikan pemahaman mengenai pentingnya kualitas data sebelum dilakukan analisis. Saya mempelajari cara mendeteksi dan menangani missing value, menghapus data duplikat, serta mengidentifikasi outlier menggunakan metode statistik.
#
# Temuan utama menunjukkan bahwa data yang kotor dapat mempengaruhi hasil analisis. Selain itu saya juga mempelajari cara mengambil data dari format JSON dan API. Keterbatasan yang masih perlu dipelajari lebih lanjut adalah pemilihan metode terbaik dalam menangani outlier pada berbagai jenis dataset.
